# %% [markdown]
# # Quick Run Demo
# This notebook shows one way to run the project script and inspect outputs.

# %%
from pathlib import Path
import subprocess

repo = Path('.').resolve()
subprocess.run(['python', str(repo / 'analysis.py')], check=False)

# %%
import pandas as pd
pd.read_csv('outputs/summary_by_region.csv').head()
